# %% [markdown]
# *ref: https://inria.github.io/scikit-learn-mooc/overfit/bias_vs_variance_slides.html*

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('VOeTTiML1pY', width=800, height=300)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
