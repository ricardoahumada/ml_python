# %% [markdown]
# *ref: https://inria.github.io/scikit-learn-mooc/overfit/learning_validation_curves_slides.html*

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('9uS4sE-UTm0', width=800, height=300)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
