# %% [markdown]
# *ref: https://inria.github.io/scikit-learn-mooc/overfit/overfitting_vs_under_fitting_slides.html*

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('xErJGDwWqys', width=800, height=300)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
