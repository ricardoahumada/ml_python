# %% [markdown]
# *ref: https://inria.github.io/scikit-learn-mooc/linear_models/linear_models_slides.html*

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('ksEGivkPP7I', width=800, height=300)

# %% [markdown]
# ![image.png](attachment:image.png)
